# %%
import os
my_var = os.getenv("GEMINI_API_KEY")
print(my_var)
print(os.environ)

# %%
from google import genai

client = genai.Client(api_key=my_var)
response = client.models.generate_content(
    model="gemini-2.0-flash", contents="Explain how AI works"
)
print(response.text)
# Out:
# Okay, let's break down how AI works, focusing on the core concepts without getting too bogged down in technical jargon.  I'll cover the main types of AI and the general processes involved.
#
# **What is AI?**
#
# At its simplest, AI (Artificial Intelligence) is about getting machines to perform tasks that typically require human intelligence.  These tasks include:
#
# *   **Learning:**  Improving performance over time based on data.
# *   **Reasoning:**  Using logic and inference to draw conclusions.
# *   **Problem-solving:**  Finding solutions to complex issues.
# *   **Perception:**  Interpreting sensory information (like images, sound, or text).
# *   **Natural Language Processing (NLP):** Understanding and generating human language.
#
# **Key Approaches to AI**
#
# AI isn't a single thing; it's a field encompassing various techniques.  Here are some of the main ones:
#
# 1.  **Machine Learning (ML):**
#
#     *   **Core Idea:** Instead of explicitly programming a machine to do something, you *train* it on data.  The machine learns patterns and relationships from the data, allowing it to make predictions or decisions on new, unseen data.
#     *   **How it Works:**
#         *   **Data:**  ML algorithms need data to learn. The more relevant and high-quality data, the better the AI will perform.
#         *   **Algorithm:**  Different ML algorithms are suited for different tasks.  Examples include:
#             *   **Supervised Learning:** You give the algorithm labeled data (e.g., images of cats labeled as "cat" and images of dogs labeled as "dog"). The algorithm learns to associate the features of the images with the correct labels. Then, you can give it a new image, and it will predict whether it's a cat or a dog.  Common algorithms include:
#                 *   **Linear Regression:**  Predicting a continuous value (e.g., predicting house prices based on size and location).
#                 *   **Logistic Regression:**  Predicting a category (e.g., spam or not spam).
#                 *   **Support Vector Machines (SVMs):**  Finding the best boundary to separate different classes of data.
#                 *   **Decision Trees:**  Creating a tree-like structure to make decisions based on a series of rules.
#                 *   **Random Forests:**  An ensemble of decision trees that often performs better than a single decision tree.
#             *   **Unsupervised Learning:**  You give the algorithm unlabeled data, and it tries to find patterns or structures on its own.  Examples include:
#                 *   **Clustering:**  Grouping similar data points together (e.g., segmenting customers into different groups based on their purchasing behavior).
#                 *   **Dimensionality Reduction:** Reducing the number of variables in a dataset while preserving its important information.
#             *   **Reinforcement Learning:**  The algorithm learns by interacting with an environment and receiving rewards or penalties for its actions.  It aims to learn a policy that maximizes its cumulative reward (e.g., training a robot to navigate a maze).
#         *   **Training:** The algorithm processes the data and adjusts its internal parameters (weights, biases, etc.) to minimize errors and improve accuracy.
#         *   **Evaluation:**  After training, you test the algorithm on a separate set of data (the "test set") to see how well it generalizes to new data.
#         *   **Deployment:**  If the algorithm performs well, it can be deployed to make predictions or decisions in the real world.
#
# 2.  **Deep Learning (DL):**
#
#     *   **Core Idea:**  A subfield of ML that uses artificial neural networks with many layers (hence "deep") to analyze data.  Deep learning excels at complex tasks like image recognition, natural language processing, and speech recognition.
#     *   **How it Works:**
#         *   **Neural Networks:**  Inspired by the structure of the human brain, neural networks consist of interconnected nodes (neurons) organized in layers.
#         *   **Layers:**
#             *   **Input Layer:**  Receives the initial data.
#             *   **Hidden Layers:**  Perform complex transformations on the data.  The more hidden layers, the "deeper" the network.
#             *   **Output Layer:**  Produces the final prediction or decision.
#         *   **Connections (Weights):**  Each connection between neurons has a weight associated with it.  These weights determine the strength of the connection.
#         *   **Activation Functions:**  Each neuron applies an activation function to its input, which introduces non-linearity and allows the network to learn complex patterns.
#         *   **Training:**  Deep learning models require massive amounts of data and computational power to train.  The training process involves adjusting the weights and biases of the network to minimize the error between the predicted output and the actual output.
#         *   **Backpropagation:**  A key algorithm used to update the weights in a neural network.  It calculates the gradient of the error function with respect to the weights and uses this gradient to adjust the weights in the direction that reduces the error.
#     *   **Examples:**
#         *   **Convolutional Neural Networks (CNNs):**  Used for image recognition and computer vision.
#         *   **Recurrent Neural Networks (RNNs):** Used for natural language processing and time series analysis.
#         *   **Transformers:** A more recent architecture that has achieved state-of-the-art results on many NLP tasks.
#
# 3.  **Rule-Based Systems (Expert Systems):**
#
#     *   **Core Idea:**  AI systems that use a set of pre-defined rules to make decisions.
#     *   **How it Works:**
#         *   **Knowledge Base:**  A collection of facts and rules about a specific domain.  These rules are typically defined by human experts.
#         *   **Inference Engine:**  Applies the rules to the facts in the knowledge base to derive new conclusions.
#         *   **User Interface:**  Allows users to interact with the system and provide input.
#     *   **Example:**  A medical diagnosis system that uses rules to diagnose diseases based on symptoms.
#     *   **Limitations:**  Difficult to maintain and update as the knowledge base grows.  Cannot handle situations that are not covered by the rules.
#
# 4.  **Natural Language Processing (NLP):**
#
#     *   **Core Idea:**  Focuses on enabling computers to understand, interpret, and generate human language.
#     *   **How it Works:**
#         *   **Text Preprocessing:**  Cleaning and preparing the text data for analysis (e.g., removing punctuation, converting to lowercase, stemming).
#         *   **Tokenization:**  Breaking down the text into individual words or phrases (tokens).
#         *   **Part-of-Speech Tagging:**  Identifying the grammatical role of each word (e.g., noun, verb, adjective).
#         *   **Named Entity Recognition:**  Identifying and classifying named entities (e.g., people, organizations, locations).
#         *   **Sentiment Analysis:**  Determining the emotional tone of the text (e.g., positive, negative, neutral).
#         *   **Machine Translation:**  Translating text from one language to another.
#         *   **Text Generation:**  Generating new text based on a given prompt or context.
#     *   **Examples:**
#         *   **Chatbots:**  Conversational AI systems that can answer questions and provide support.
#         *   **Speech Recognition:**  Converting speech to text.
#         *   **Text Summarization:**  Generating a concise summary of a longer text.
#
# **The General Process of Building an AI System**
#
# While the specifics vary depending on the type of AI and the problem being solved, here's a general overview:
#
# 1.  **Define the Problem:**  Clearly identify the goal of the AI system. What problem are you trying to solve? What tasks should the AI be able to perform?
# 2.  **Gather Data:**  Collect a large and relevant dataset that can be used to train the AI model.
# 3.  **Prepare the Data:**  Clean and pre-process the data to ensure it is in a suitable format for training. This may involve removing errors, handling missing values, and transforming the data.
# 4.  **Choose an Algorithm:**  Select the appropriate AI algorithm based on the problem and the data.
# 5.  **Train the Model:**  Train the AI model on the prepared data. This involves adjusting the model's parameters to minimize the error between its predictions and the actual values.
# 6.  **Evaluate the Model:**  Evaluate the performance of the trained model on a separate test dataset. This helps to assess how well the model generalizes to new, unseen data.
# 7.  **Tune the Model:**  Adjust the model's parameters or architecture to improve its performance. This may involve experimenting with different algorithms, hyperparameters, or data preprocessing techniques.
# 8.  **Deploy the Model:**  Deploy the trained model to a production environment where it can be used to make predictions or decisions in real-time.
# 9.  **Monitor and Maintain:**  Continuously monitor the performance of the deployed model and retrain it as needed to ensure it remains accurate and effective.
#
# **Important Considerations**
#
# *   **Bias:**  AI models can inherit biases from the data they are trained on.  It's crucial to be aware of potential biases and take steps to mitigate them.
# *   **Explainability:**  Some AI models (especially deep learning models) are difficult to interpret.  Understanding how an AI makes its decisions is important for building trust and ensuring accountability.
# *   **Ethics:**  AI raises ethical concerns about privacy, fairness, and the potential for misuse.  It's important to develop and use AI responsibly.
# *   **Data is King (or Queen):** The quality and quantity of data are critical to the success of any AI project.
#
# **In Summary**
#
# AI is a broad field that aims to create machines capable of intelligent behavior.  Machine learning, deep learning, rule-based systems, and NLP are some of the key approaches used to build AI systems. The general process involves defining the problem, gathering data, training a model, evaluating its performance, and deploying it to a production environment. It's also crucial to consider ethical implications and address potential biases in AI systems.  I hope this explanation is helpful!

# %%
response = client.models.generate_content_stream(
    model="gemini-2.0-flash",
    contents=["Explain how AI works"]
)
for chunk in response:
    print(chunk.text, end="")
# Out:
# Okay, let's break down how AI works in a way that's understandable, even if you don't have a computer science background.  I'll try to avoid getting too technical, but I'll also give you some core concepts.
#
# **The Basic Idea: Mimicking Intelligence**
#
# At its heart, Artificial Intelligence (AI) is about creating computer systems that can perform tasks that typically require human intelligence. This includes things like:
#
# *   **Learning:**  Improving performance over time based on data.
# *   **Reasoning:**  Drawing conclusions from information.
# *   **Problem Solving:** Finding solutions to complex issues.
# *   **Perception:** Understanding sensory input (like images, sound, or text).
# *   **Natural Language Processing:** Understanding and generating human language.
#
# **Key Components & Approaches**
#
# Think of AI as an umbrella term covering a lot of different techniques. Here are some of the most important:
#
# 1.  **Machine Learning (ML): The Learning Engine**
#
#     *   **What it is:** Machine learning is the most common way to achieve AI. Instead of explicitly programming a computer to do something, you *train* it using large amounts of data. The algorithm learns patterns from the data and then uses those patterns to make predictions or decisions on new, unseen data.
#
#     *   **How it works (Simplified):**
#
#         *   **Data Input:** You feed the algorithm a dataset (e.g., images of cats and dogs, customer purchase histories, text from news articles).
#         *   **Feature Extraction:** The algorithm (or you) identifies important features in the data (e.g., for images: edges, colors, textures; for text: words, phrases, sentiment).
#         *   **Model Building:** The algorithm builds a model (a mathematical representation) that maps the input features to the desired output (e.g., cat or dog, predict future sales, identify the topic of an article).
#         *   **Training:** The algorithm adjusts the model's parameters to minimize errors in its predictions. This is often done using a feedback loop where the algorithm makes a prediction, compares it to the correct answer, and then adjusts its parameters to get closer to the correct answer next time.
#         *   **Testing/Evaluation:**  You test the model on a separate set of data (that it hasn't seen before) to see how well it generalizes.
#         *   **Deployment:** If the model performs well, you deploy it to make predictions on new data.
#
#     *   **Types of Machine Learning:**
#
#         *   **Supervised Learning:**  You give the algorithm labeled data (e.g., "this image is a cat," "this customer churned"). The algorithm learns to predict the labels for new data.  Examples: image classification, spam detection, regression (predicting a numerical value).
#         *   **Unsupervised Learning:** You give the algorithm unlabeled data (e.g., a bunch of customer data without telling it which customers are similar). The algorithm tries to find patterns and structures in the data on its own. Examples: clustering (grouping similar customers), dimensionality reduction (simplifying complex data), anomaly detection (finding unusual events).
#         *   **Reinforcement Learning:**  The algorithm learns by interacting with an environment and receiving rewards or penalties for its actions. Think of it like training a dog with treats. Examples: game playing (like AlphaGo), robotics, autonomous driving.
#
# 2.  **Deep Learning (DL):  The Powerhouse of Modern AI**
#
#     *   **What it is:** Deep learning is a subfield of machine learning that uses artificial neural networks with many layers (hence "deep").  These networks are inspired by the structure of the human brain.
#
#     *   **How it works (Simplified):**
#
#         *   Deep neural networks consist of interconnected nodes (neurons) organized in layers.
#         *   Input data is fed into the first layer.
#         *   Each neuron performs a simple calculation on its inputs and passes the result to the neurons in the next layer.
#         *   As the data passes through the layers, the network learns to extract increasingly complex features from the data.
#         *   The final layer outputs the prediction.
#
#     *   **Why it's powerful:** Deep learning can automatically learn complex features from raw data, without needing manual feature engineering. It's particularly effective for tasks like image recognition, natural language processing, and speech recognition.  However, it typically requires a *lot* of data and computational power.
#
# 3.  **Natural Language Processing (NLP):  Understanding and Generating Language**
#
#     *   **What it is:** NLP focuses on enabling computers to understand, interpret, and generate human language.
#
#     *   **Examples:**
#
#         *   **Machine Translation:** Translating text from one language to another (e.g., Google Translate).
#         *   **Sentiment Analysis:** Determining the emotional tone of a piece of text (e.g., positive, negative, neutral).
#         *   **Chatbots:**  Creating conversational agents that can interact with humans.
#         *   **Text Summarization:**  Generating a concise summary of a longer text.
#         *   **Speech Recognition:** Converting spoken language into text.
#         *   **Text Generation:** Creating new text, such as articles, stories, or code.
#
#     *   **Techniques:** NLP uses a combination of machine learning, deep learning, and linguistic rules to process language.
#
# 4.  **Computer Vision:  Seeing Like a Computer**
#
#     *   **What it is:** Computer vision enables computers to "see" and interpret images and videos.
#
#     *   **Examples:**
#
#         *   **Object Detection:** Identifying objects in an image (e.g., cars, pedestrians, trees).
#         *   **Image Recognition:** Classifying an image (e.g., "this is a cat").
#         *   **Facial Recognition:** Identifying faces in an image.
#         *   **Image Segmentation:** Dividing an image into regions (e.g., separating the foreground from the background).
#
#     *   **Techniques:** Computer vision heavily relies on deep learning, particularly convolutional neural networks (CNNs), to analyze images.
#
# 5.  **Rule-Based Systems (Expert Systems): The Old School Approach**
#
#     *   **What it is:** These systems use a set of predefined rules to make decisions.  They are based on human expertise.
#
#     *   **How it works:**
#         *   A knowledge engineer interviews experts in a specific domain and translates their knowledge into a set of "if-then" rules.
#         *   The system uses these rules to reason about new situations and provide recommendations.
#
#     *   **Limitations:**  Rule-based systems are good for well-defined problems with limited complexity, but they are difficult to scale and maintain when the problem domain is large or constantly changing. They also lack the ability to learn from data.  Less common now, but still used in some specific applications.
#
# **The AI Development Process (General Outline)**
#
# 1.  **Define the Problem:** What specific task do you want the AI to perform?
# 2.  **Gather Data:** Collect a large and relevant dataset for training.  Data quality is crucial!
# 3.  **Choose an Algorithm/Approach:** Select the appropriate machine learning algorithm or AI technique based on the problem and the data.
# 4.  **Train the Model:** Train the algorithm on the data to build a model.
# 5.  **Evaluate the Model:** Test the model on a separate dataset to assess its performance.
# 6.  **Tune the Model:** Adjust the model's parameters to improve its accuracy and performance.
# 7.  **Deploy the Model:** Integrate the model into a real-world application.
# 8.  **Monitor and Maintain:** Continuously monitor the model's performance and retrain it as needed to keep it up-to-date.
#
# **Important Considerations**
#
# *   **Data is King:** AI models are only as good as the data they are trained on.  Biased data can lead to biased models.
# *   **Computational Power:** Training complex AI models, especially deep learning models, requires significant computational resources (GPUs, TPUs).
# *   **Explainability:**  Understanding *why* an AI model makes a particular decision is important, especially in critical applications (e.g., healthcare, finance).  This is an area of active research (Explainable AI or XAI).
# *   **Ethics:** AI raises ethical concerns about bias, fairness, privacy, and job displacement.  It's important to develop and use AI responsibly.
#
# **In Summary**
#
# AI is a broad field that aims to create intelligent machines. Machine learning, especially deep learning, is the most common approach. These techniques involve training algorithms on large datasets to learn patterns and make predictions.  NLP and computer vision are important subfields that focus on enabling computers to understand language and images, respectively.  The key is to define the problem clearly, gather good data, choose the right algorithm, and evaluate and tune the model carefully.
#
# This is a simplified overview, but I hope it gives you a good understanding of how AI works! Let me know if you have any more specific questions.

# %%
chat = client.chats.create(model="gemini-2.0-flash")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)
# Out:
# That's wonderful! Dogs bring so much joy to a home. Do you want to tell me anything else about them? Like their names, breeds, or favorite activities?

# %%
response = chat.send_message("How many paws are in my house?")
print(response.text)

for message in chat.get_history():
    print(f'role - {message.role}',end=": ")
    print(message.parts[0].text)
# Out:
# Since you have two dogs, and each dog has four paws, there are a total of 8 paws in your house.
#
# role - user: I have 2 dogs in my house.
# role - model: That's wonderful! Dogs bring so much joy to a home. Do you want to tell me anything else about them? Like their names, breeds, or favorite activities?
#
# role - user: How many paws are in my house?
# role - model: Since you have two dogs, and each dog has four paws, there are a total of 8 paws in your house.
